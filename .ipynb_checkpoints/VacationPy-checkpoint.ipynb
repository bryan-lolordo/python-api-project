# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0        0  acapulco de juarez  16.8634  -99.8901     30.90        66
# 1        1            hermanus -34.4187   19.2345      8.92        79
# 2        2           iskateley  67.6803   53.1512     11.13        84
# 3        3             yakeshi  49.2833  120.7333     10.61        52
# 4        4         west island -12.1568   96.8225     25.99        78
#
#    Cloudiness  Wind Speed Country        Date
# 0          40        4.12      MX  1694566028
# 1           0        4.88      ZA  1694566112
# 2          13        7.38      RU  1694566112
# 3         100        2.34      CN  1694566112
# 4          75        6.17      CC  1694566112

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

#need to find out other things to add to hvplot

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    color = "City",
    tiles = "OSM"
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
narrowed_city_data_df = city_data_df[(city_data_df["Max Temp"] > 24) & 
                                (city_data_df["Max Temp"] <= 30) & \
                                (city_data_df["Humidity"] < 85)]


# Drop any rows with null values
# YOUR CODE HERE
narrowed_city_data_df = narrowed_city_data_df.dropna()


# Display sample data
# YOUR CODE HERE
narrowed_city_data_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 4          4        west island -12.1568   96.8225     25.99        78
# 12        12  wailua homesteads  22.0669 -159.3780     28.44        64
# 19        19          al muwayh  22.4333   41.7583     28.90        28
# 20        20               daru  -9.0763  143.2092     27.06        66
# 28        28    remire-montjoly   4.9167  -52.2667     27.02        83
# ..       ...                ...      ...       ...       ...       ...
# 546      546        san mariano   7.5000  126.0000     27.55        74
# 549      549              basco  20.4487  121.9702     27.40        70
# 552      552           lospalos  -8.5186  127.0025     25.38        67
# 555      555             dwarka  22.2394   68.9678     27.05        83
# 560      560          key largo  25.0865  -80.4473     29.44        73
#
#      Cloudiness  Wind Speed Country        Date
# 4            75        6.17      CC  1694566112
# 12           20        6.17      US  1694566113
# 19           97        3.41      SA  1694566114
# 20           98        7.43      PG  1694566114
# 28            0        2.06      GF  1694566115
# ..          ...         ...     ...         ...
# 546         100        1.37      PH  1694566190
# 549          21        1.44      PH  1694566190
# 552          46        5.15      TL  1694566191
# 555          64        5.48      IN  1694566191
# 560          20        6.25      US  1694566091
#
# [141 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = narrowed_city_data_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()
hotel_df

hotel_df["Hotel Name"] = ""


# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                   City Country      Lat       Lng  Humidity Hotel Name
# 4          west island      CC -12.1568   96.8225        78
# 12   wailua homesteads      US  22.0669 -159.3780        64
# 19           al muwayh      SA  22.4333   41.7583        28
# 20                daru      PG  -9.0763  143.2092        66
# 28     remire-montjoly      GF   4.9167  -52.2667        83
# ..                 ...     ...      ...       ...       ...        ...
# 546        san mariano      PH   7.5000  126.0000        74
# 549              basco      PH  20.4487  121.9702        70
# 552           lospalos      TL  -8.5186  127.0025        67
# 555             dwarka      IN  22.2394   68.9678        83
# 560          key largo      US  25.0865  -80.4473        73
#
# [141 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 50

#do we need to parameters for bias, limit, and filters as well?

params = {
    "limit": limit,
    "apiKey": geoapify_key,
    "categories": "accommodation.hotel"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
       
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()

    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# west island - nearest hotel: Cocos Village Bungalows
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# al muwayh - nearest hotel: فندق ومطعم الموية
# daru - nearest hotel: Kuki
# remire-montjoly - nearest hotel: Complexe Belova
# hawaiian paradise park - nearest hotel: No hotel found
# udangudi - nearest hotel: No hotel found
# massakory - nearest hotel: No hotel found
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# kulhudhuffushi - nearest hotel: No hotel found
# utrik - nearest hotel: No hotel found
# ghadamis - nearest hotel: فندق عين الفارس
# bikenibeu village - nearest hotel: Otintaai Hotel
# malvan - nearest hotel: Hotel Silver Sand
# dhidhdhoo - nearest hotel: Cinnamon Island
# ziniare - nearest hotel: Residence Les Saints Innocents
# isangel - nearest hotel: Tanna Lodge
# beihai - nearest hotel: Pearl Bay Seaview Hotel
# georgetown - nearest hotel: Page 63 hostel
# bayji - nearest hotel: No hotel found
# hilo - nearest hotel: Dolphin Bay Hotel
# holualoa - nearest hotel: Kona Hotel
# alofi - nearest hotel: Matavai Resort
# enewetak - nearest hotel: No hotel found
# mejit - nearest hotel: No hotel found
# guerrero negro - nearest hotel: Plaza sal paraiso
# avarua - nearest hotel: Paradise Inn
# waingapu - nearest hotel: HOTEL SANDLEWOOD
# kos - nearest hotel: MARITINA
# afaahiti - nearest hotel: Omati Lodge
# mazagao - nearest hotel: No hotel found
# angaur state - nearest hotel: No hotel found
# kirakira - nearest hotel: No hotel found
# shache - nearest hotel: 莎車新盛賓舘
# port moresby - nearest hotel: The Sanctuary Hotel and Spa
# sinabang - nearest hotel: No hotel found
# altamira - nearest hotel: Hotel Vale do Xingu
# bengkulu - nearest hotel: Dena Hotel
# gijang - nearest hotel: 힐튼호텔 부산
# biltine - nearest hotel: فندق ثلاث نجوم بلتن
# kangaba - nearest hotel: Hôtel Mande
# hadibu - nearest hotel: No hotel found
# shingu - nearest hotel: ホテルニューパレス
# mpongwe - nearest hotel: No hotel found
# fale old settlement - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# kailua-kona - nearest hotel: Kona Seaside Hotel
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# lihue - nearest hotel: Kauai Palms
# bafoulabe - nearest hotel: No hotel found
# gereida - nearest hotel: No hotel found
# kiunga - nearest hotel: No hotel found
# orai - nearest hotel: Hotel Jaiswal tower
# mount isa - nearest hotel: Ibis Styles
# las praderas - nearest hotel: Hotel Internacional
# cockburn town - nearest hotel: The Salt Raker Inn
# medicine hat - nearest hotel: Ramada
# srandakan - nearest hotel: Puri Ganjuran
# les anglais - nearest hotel: No hotel found
# tari - nearest hotel: No hotel found
# effingham - nearest hotel: No hotel found
# puerto lleras - nearest hotel: No hotel found
# al kawa - nearest hotel: No hotel found
# atafu village - nearest hotel: No hotel found
# muroto-misakicho - nearest hotel: 民宿うらしま
# mehtar lam - nearest hotel: No hotel found
# shengli - nearest hotel: 大明大厦酒店
# san luis de la loma - nearest hotel: No hotel found
# puerto san jose - nearest hotel: Martita
# hami - nearest hotel: Хами
# bubaque - nearest hotel: Chez Julio
# hithadhoo - nearest hotel: Pebbles Inn
# luwuk - nearest hotel: No hotel found
# santa cruz - nearest hotel: Aviador Hotel Boutique
# titao - nearest hotel: Auberge
# san andres - nearest hotel: Hotel Decameron Isleño
# bebedouro - nearest hotel: No hotel found
# porbandar - nearest hotel: Toran Tourist Bungalow
# guozhen - nearest hotel: No hotel found
# elesbao veloso - nearest hotel: No hotel found
# ocean city - nearest hotel: Watson's Regency Suites
# wanning - nearest hotel: No hotel found
# singaraja - nearest hotel: Hotel Sentral
# murzuq - nearest hotel: فندق باريس - مرزق
# uturoa - nearest hotel: Hawaiki Nui hotel
# manggar - nearest hotel: No hotel found
# cururupu - nearest hotel: No hotel found
# pemangkat - nearest hotel: Hotel Kelapa Gading
# mandera - nearest hotel: Kornesh Hotel and Lodging
# ghat - nearest hotel: فندق تاسيلي
# ciudad lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# kununurra - nearest hotel: Kununurra Country Club Resort
# kavaratti - nearest hotel: No hotel found
# kavieng - nearest hotel: Kavieng Hotel
# port-vila - nearest hotel: Holiday Inn Resort Vanuatu
# barah - nearest hotel: No hotel found
# zhongshan - nearest hotel: No hotel found
# suva - nearest hotel: Extension 68
# beledweyne - nearest hotel: Hotel Medina
# salalah - nearest hotel: Muscat International Hotel
# bandarbeyla - nearest hotel: No hotel found
# ati - nearest hotel: No hotel found
# tucuma - nearest hotel: No hotel found
# oum hadjer - nearest hotel: No hotel found
# tabuk - nearest hotel: Davidson Hotel
# kashmor - nearest hotel: No hotel found
# kapa'a - nearest hotel: Pono Kai Resort
# papao - nearest hotel: Hiti Moana Villa Lodge
# iwanai - nearest hotel: ホチルいのう
# manokwari - nearest hotel: Hotel Arfak
# balikpapan - nearest hotel: Hotel Grand Senyiur
# laminusa - nearest hotel: No hotel found
# miguel ahumada - nearest hotel: Hotel Mexico
# kabalo - nearest hotel: No hotel found
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# nova sintra - nearest hotel: Residência Ka Dencho
# cody - nearest hotel: Comfort Inn At Buffalo Bill Village Resort
# sabang - nearest hotel: Sabang Hill
# qui nhon - nearest hotel: TMS Quy Nhơn - Home ở đây!
# maine soroa - nearest hotel: Maïné-Soroa
# kralendijk - nearest hotel: Hotel Bonaire Inn
# bandundu - nearest hotel: Majestik Hotel
# carutapera - nearest hotel: No hotel found
# baardheere - nearest hotel: No hotel found
# oodweyne - nearest hotel: فندق المدينه
# ilha de mocambique - nearest hotel: Ruby Backpackers
# ende - nearest hotel: LCR Hotel
# nioki - nearest hotel: No hotel found
# sao vicente - nearest hotel: Pousada Vitória
# nadi - nearest hotel: President Hotel
# gadsden - nearest hotel: Super 8 by Wyndham Gadsden AL
# kourou - nearest hotel: SCI Horizon
# barreirinhas - nearest hotel: Pousada Matriz
# salahonda - nearest hotel: No hotel found
# albina - nearest hotel: Amazonie accueil
# ad dawadimi - nearest hotel: No hotel found
# san mariano - nearest hotel: No hotel found
# basco - nearest hotel: Tawsen Hotel
# lospalos - nearest hotel: Hotel Roberto Carlos
# dwarka - nearest hotel: The Dwarika Hotel
# key largo - nearest hotel: Key Largo Inn
#                   City Country      Lat       Lng  Humidity  \
# 4          west island      CC -12.1568   96.8225        78
# 12   wailua homesteads      US  22.0669 -159.3780        64
# 19           al muwayh      SA  22.4333   41.7583        28
# 20                daru      PG  -9.0763  143.2092        66
# 28     remire-montjoly      GF   4.9167  -52.2667        83
# ..                 ...     ...      ...       ...       ...
# 546        san mariano      PH   7.5000  126.0000        74
# 549              basco      PH  20.4487  121.9702        70
# 552           lospalos      TL  -8.5186  127.0025        67
# 555             dwarka      IN  22.2394   68.9678        83
# 560          key largo      US  25.0865  -80.4473        73
#
#                              Hotel Name
# 4               Cocos Village Bungalows
# 12   Hilton Garden Inn Kauai Wailua Bay
# 19                    فندق ومطعم الموية
# 20                                 Kuki
# 28                      Complexe Belova
# ..                                  ...
# 546                      No hotel found
# 549                        Tawsen Hotel
# 552                Hotel Roberto Carlos
# 555                   The Dwarika Hotel
# 560                       Key Largo Inn
#
# [141 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

hotel_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    color = "City",
    tiles = "OSM",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
hotel_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
